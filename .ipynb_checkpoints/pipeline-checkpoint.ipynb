# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
checkpoint = "distilbert-base-uncased-finetuned-sst-2-english"

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
data = ["i'm so happy"]

# %%
inputs = tokenizer(data, padding=True, truncation=True, return_tensors="pt")

# %%
print(inputs)
# Out:
# {'input_ids': tensor([[ 101, 1045, 1005, 1049, 2061, 3407,  102]]), 'token_type_ids': tensor([[0, 0, 0, 0, 0, 0, 0]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1, 1]])}

# %%
output = model(**inputs)

# %%
print(output.logits)
# Out:
# tensor([[-4.3393,  4.6967]], grad_fn=<AddmmBackward0>)

# %%
import torch

# %%
predictions = torch.nn.functional.softmax(output.logits, dim=-1)
print(predictions)
# Out:
# tensor([[1.1903e-04, 9.9988e-01]], grad_fn=<SoftmaxBackward0>)
